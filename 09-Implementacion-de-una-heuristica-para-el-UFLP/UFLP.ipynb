# %% [markdown]
#  Solución óptima o mejor conocida
#
#       UFLP-1
#
#  23468
#
#       UFLP-2
#
#  22119
#
#       UFLP-3
#
#  25038
#
#       UFLP-4
#
#  21864
#
#       UFLP-5
#
#  23976
#
#       UFLP-6
#
#  257964
#
#       UFLP-7
#
#  257961
#
#       UFLP-8
#
#  257626
#
#       UFLP-9
#
#  257573
#
#       UFLP-10
#
#  257896

# %% [markdown]
#  Solución óptima o mejor conocida
#
#       UFLP-1
#
#  23468
#
#       UFLP-2
#
#  22119
#
#       UFLP-3
#
#  25038
#
#       UFLP-4
#
#  21864
#
#       UFLP-5
#
#  23976
#
#       UFLP-6
#
#  257964
#
#       UFLP-7
#
#  257961
#
#       UFLP-8
#
#  257626
#
#       UFLP-9
#
#  257573
#
#       UFLP-10
#
#  257896
