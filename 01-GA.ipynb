# %% [markdown]
# <style>
# body {
#     max-width: 900px;
#     margin: 40px auto;
#     padding: 0 20px;
#     font-family: "Georgia", serif;
#     line-height: 1.6;
# }
# </style>
#
# <div style="text-align: center; padding: 60px 60px">
#   <h1 style="font-weight: bold; font-size: 3.1em">
#     GA-UFLP-1
#   </h1>
# </div>

# %% [markdown]
# ## **CONFIGURACIÓN DE LA NOTEBOOK**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
from cargar_datos import *
from ga_uflp import *

# %% [markdown]
# # **CARGAR DATOS**

# %%
file_name = 'UFLP-1'

# %%
n_instalaciones, n_clientes, costos_fijos, costos_de_transporte = cargar_datos('datos/'+file_name+'.txt')

# %% [markdown]
# # **BÚSQUEDA DE HIPERPARÁMETROS**

# %%
num_ejecuciones = 100
resultados = {}
random_seed = 8

path = "resultados"
os.makedirs(os.path.join(path, file_name), exist_ok=True)

# %%
configuraciones = [
    {
        "tamaño_de_poblacion": 100,
        "tasa_de_mutacion": 0,
        "tasa_de_crossover": 0,
        "tamaño_del_torneo": 10,
        "maximo_de_generaciones": 30,
        "tipo_de_crossover": "un punto"
    },
    {
        "tamaño_de_poblacion": 100,
        "tasa_de_mutacion": .2,
        "tasa_de_crossover": 0,
        "tamaño_del_torneo": 10,
        "maximo_de_generaciones": 30,
        "tipo_de_crossover": "un punto"
    },
    {
        "tamaño_de_poblacion": 100,
        "tasa_de_mutacion": .4,
        "tasa_de_crossover": 0,
        "tamaño_del_torneo": 10,
        "maximo_de_generaciones": 30,
        "tipo_de_crossover": "un punto"
    },
    {
        "tamaño_de_poblacion": 100,
        "tasa_de_mutacion": .6,
        "tasa_de_crossover": 0,
        "tamaño_del_torneo": 10,
        "maximo_de_generaciones": 30,
        "tipo_de_crossover": "un punto"
    },
    {
        "tamaño_de_poblacion": 100,
        "tasa_de_mutacion": .8,
        "tasa_de_crossover": 0,
        "tamaño_del_torneo": 10,
        "maximo_de_generaciones": 30,
        "tipo_de_crossover": "un punto"
    },
    {
        "tamaño_de_poblacion": 100,
        "tasa_de_mutacion": 1,
        "tasa_de_crossover": 0,
        "tamaño_del_torneo": 10,
        "maximo_de_generaciones": 30,
        "tipo_de_crossover": "un punto"
    },
]

# %% [markdown]
# ## **EJECUCIÓN**

# %%
print(f"Ejecutando GA para {file_name} con semilla aleatoria: {random_seed}\n")

for config in configuraciones:
    nombre_configuracion = f"N={config['tamaño_de_poblacion']}, M={config['tasa_de_mutacion']}, C={config['tasa_de_crossover']}, T={config['tamaño_del_torneo']}, G={config['maximo_de_generaciones']}, tc={config['tipo_de_crossover']}"
    print(f"--- Ejecutando configuracion: {nombre_configuracion} ---")
    resultados[nombre_configuracion] = []

    for ejecucion in range(num_ejecuciones):
        ga = UFLP_GA(n_instalaciones, n_clientes, costos_fijos, costos_de_transporte,
                     config["tamaño_de_poblacion"], config["tasa_de_mutacion"], config["tasa_de_crossover"],
                     config["tamaño_del_torneo"], config["maximo_de_generaciones"])
        if config["tipo_de_crossover"] == "uniforme":
            ga._operador_de_crossover = ga._crossover_uniforme
        elif config["tipo_de_crossover"] == "un punto":
            ga._operador_de_crossover = ga._crossover_un_punto
        else:
            raise ValueError(f"Tipo de crossover desconocido: {config['tipo_de_crossover']}")

        mejor_solucion, mejor_fitness, historial_de_fitnesses, tiempo_de_ejecucion, num_generaciones = ga.run()
        resultados[nombre_configuracion].append({
            "mejor_solucion": mejor_solucion+1,
            "mejor_costo": mejor_fitness,
            "tiempo_de_ejecucion": tiempo_de_ejecucion,
            "num_generaciones": num_generaciones,
            "historial_de_fitnesses": historial_de_fitnesses
        })
        print(f"Ejecucion {ejecucion + 1}/{num_ejecuciones}: Mejor Costo = {mejor_fitness:.2f}, Tiempo = {tiempo_de_ejecucion:.2f}s, Generaciones = {num_generaciones}")
    print("\n")
# Out:
# Ejecutando GA para UFLP-1 con semilla aleatoria: 8
#
# --- Ejecutando configuracion: N=100, M=0, C=0, T=10, G=30, tc=un punto ---
# Ejecucion 1/100: Mejor Costo = 40641.00, Tiempo = 0.42s, Generaciones = 30
# Ejecucion 2/100: Mejor Costo = 40053.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 3/100: Mejor Costo = 32725.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 4/100: Mejor Costo = 39186.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 5/100: Mejor Costo = 41474.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 6/100: Mejor Costo = 39480.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 7/100: Mejor Costo = 33169.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 8/100: Mejor Costo = 34367.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 9/100: Mejor Costo = 30381.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 10/100: Mejor Costo = 37722.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 11/100: Mejor Costo = 32480.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 12/100: Mejor Costo = 39503.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 13/100: Mejor Costo = 37642.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 14/100: Mejor Costo = 40387.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 15/100: Mejor Costo = 34496.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 16/100: Mejor Costo = 41101.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 17/100: Mejor Costo = 40539.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 18/100: Mejor Costo = 38892.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 19/100: Mejor Costo = 37196.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 20/100: Mejor Costo = 35725.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 21/100: Mejor Costo = 37629.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 22/100: Mejor Costo = 36289.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 23/100: Mejor Costo = 44097.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 24/100: Mejor Costo = 36719.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 25/100: Mejor Costo = 34333.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 26/100: Mejor Costo = 45940.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 27/100: Mejor Costo = 38428.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 28/100: Mejor Costo = 36805.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 29/100: Mejor Costo = 41503.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 30/100: Mejor Costo = 35062.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 31/100: Mejor Costo = 42513.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 32/100: Mejor Costo = 41197.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 33/100: Mejor Costo = 34087.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 34/100: Mejor Costo = 41859.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 35/100: Mejor Costo = 38194.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 36/100: Mejor Costo = 38127.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 37/100: Mejor Costo = 37652.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 38/100: Mejor Costo = 39439.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 39/100: Mejor Costo = 34817.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 40/100: Mejor Costo = 41345.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 41/100: Mejor Costo = 31806.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 42/100: Mejor Costo = 34047.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 43/100: Mejor Costo = 36982.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 44/100: Mejor Costo = 32229.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 45/100: Mejor Costo = 38623.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 46/100: Mejor Costo = 38874.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 47/100: Mejor Costo = 40162.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 48/100: Mejor Costo = 31725.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 49/100: Mejor Costo = 34798.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 50/100: Mejor Costo = 36718.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 51/100: Mejor Costo = 38022.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 52/100: Mejor Costo = 34757.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 53/100: Mejor Costo = 33388.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 54/100: Mejor Costo = 39591.00, Tiempo = 0.03s, Generaciones = 30
# Ejecucion 55/100: Mejor Costo = 37720.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 56/100: Mejor Costo = 37358.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 57/100: Mejor Costo = 37637.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 58/100: Mejor Costo = 37482.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 59/100: Mejor Costo = 42360.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 60/100: Mejor Costo = 41967.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 61/100: Mejor Costo = 41443.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 62/100: Mejor Costo = 33863.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 63/100: Mejor Costo = 33868.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 64/100: Mejor Costo = 36805.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 65/100: Mejor Costo = 44172.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 66/100: Mejor Costo = 40035.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 67/100: Mejor Costo = 38372.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 68/100: Mejor Costo = 41968.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 69/100: Mejor Costo = 34503.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 70/100: Mejor Costo = 39714.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 71/100: Mejor Costo = 36686.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 72/100: Mejor Costo = 38183.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 73/100: Mejor Costo = 34398.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 74/100: Mejor Costo = 39322.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 75/100: Mejor Costo = 38096.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 76/100: Mejor Costo = 38239.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 77/100: Mejor Costo = 36026.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 78/100: Mejor Costo = 33705.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 79/100: Mejor Costo = 31503.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 80/100: Mejor Costo = 36539.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 81/100: Mejor Costo = 37995.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 82/100: Mejor Costo = 41593.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 83/100: Mejor Costo = 44501.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 84/100: Mejor Costo = 36116.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 85/100: Mejor Costo = 39209.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 86/100: Mejor Costo = 39177.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 87/100: Mejor Costo = 38468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 88/100: Mejor Costo = 35242.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 89/100: Mejor Costo = 37292.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 90/100: Mejor Costo = 33377.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 91/100: Mejor Costo = 33212.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 92/100: Mejor Costo = 33224.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 93/100: Mejor Costo = 38503.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 94/100: Mejor Costo = 37938.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 95/100: Mejor Costo = 41530.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 96/100: Mejor Costo = 41476.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 97/100: Mejor Costo = 35289.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 98/100: Mejor Costo = 31404.00, Tiempo = 0.03s, Generaciones = 30
# Ejecucion 99/100: Mejor Costo = 37825.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 100/100: Mejor Costo = 37162.00, Tiempo = 0.04s, Generaciones = 30
#
#
# --- Ejecutando configuracion: N=100, M=0.2, C=0, T=10, G=30, tc=un punto ---
# Ejecucion 1/100: Mejor Costo = 23932.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 2/100: Mejor Costo = 24097.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 3/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 4/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 5/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 6/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 7/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 8/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 9/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 10/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 11/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 12/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 13/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 14/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 15/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 16/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 17/100: Mejor Costo = 23932.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 18/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 19/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 20/100: Mejor Costo = 24105.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 21/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 22/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 23/100: Mejor Costo = 23932.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 24/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 25/100: Mejor Costo = 23919.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 26/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 27/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 28/100: Mejor Costo = 23932.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 29/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 30/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 31/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 32/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 33/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 34/100: Mejor Costo = 24105.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 35/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 36/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 37/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 38/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 39/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 40/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 41/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 42/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 43/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 44/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 45/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 46/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 47/100: Mejor Costo = 23932.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 48/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 49/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 50/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 51/100: Mejor Costo = 23932.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 52/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 53/100: Mejor Costo = 23897.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 54/100: Mejor Costo = 23897.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 55/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 56/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 57/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 58/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 59/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 60/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 61/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 62/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 63/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 64/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 65/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 66/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 67/100: Mejor Costo = 23932.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 68/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 69/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 70/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 71/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 72/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 73/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 74/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 75/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 76/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 77/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 78/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 79/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 80/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 81/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 82/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 83/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 84/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 85/100: Mejor Costo = 24127.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 86/100: Mejor Costo = 23932.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 87/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 88/100: Mejor Costo = 23932.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 89/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 90/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 91/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 92/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 93/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 94/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 95/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 96/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 97/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 98/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 99/100: Mejor Costo = 23468.00, Tiempo = 0.04s, Generaciones = 30
# Ejecucion 100/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
#
#
# --- Ejecutando configuracion: N=100, M=0.4, C=0, T=10, G=30, tc=un punto ---
# Ejecucion 1/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 2/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 3/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 4/100: Mejor Costo = 23932.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 5/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 6/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 7/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 8/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 9/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 10/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 11/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 12/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 13/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 14/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 15/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 16/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 17/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 18/100: Mejor Costo = 23932.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 19/100: Mejor Costo = 23468.00, Tiempo = 0.14s, Generaciones = 30
# Ejecucion 20/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 21/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 22/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 23/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 24/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 25/100: Mejor Costo = 23919.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 26/100: Mejor Costo = 23919.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 27/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 28/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 29/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 30/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 31/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 32/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 33/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 34/100: Mejor Costo = 23932.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 35/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 36/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 37/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 38/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 39/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 40/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 41/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 42/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 43/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 44/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 45/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 46/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 47/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 48/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 49/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 50/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 51/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 52/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 53/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 54/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 55/100: Mejor Costo = 23897.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 56/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 57/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 58/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 59/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 60/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 61/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 62/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 63/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 64/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 65/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 66/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 67/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 68/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 69/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 70/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 71/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 72/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 73/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 74/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 75/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 76/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 77/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 78/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 79/100: Mejor Costo = 23932.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 80/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 81/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 82/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 83/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 84/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 85/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 86/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 87/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 88/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 89/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 90/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 91/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 92/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 93/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 94/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 95/100: Mejor Costo = 23919.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 96/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 97/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 98/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 99/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 100/100: Mejor Costo = 23919.00, Tiempo = 0.05s, Generaciones = 30
#
#
# --- Ejecutando configuracion: N=100, M=0.6, C=0, T=10, G=30, tc=un punto ---
# Ejecucion 1/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 2/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 3/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 4/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 5/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 6/100: Mejor Costo = 23932.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 7/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 8/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 9/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 10/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 11/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 12/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 13/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 14/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 15/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 16/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 17/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 18/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 19/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 20/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 21/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 22/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 23/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 24/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 25/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 26/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 27/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 28/100: Mejor Costo = 23919.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 29/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 30/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 31/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 32/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 33/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 34/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 35/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 36/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 37/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 38/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 39/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 40/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 41/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 42/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 43/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 44/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 45/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 46/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 47/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 48/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 49/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 50/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 51/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 52/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 53/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 54/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 55/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 56/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 57/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 58/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 59/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 60/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 61/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 62/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 63/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 64/100: Mejor Costo = 23932.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 65/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 66/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 67/100: Mejor Costo = 23897.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 68/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 69/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 70/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 71/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 72/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 73/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 74/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 75/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 76/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 77/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 78/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 79/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 80/100: Mejor Costo = 23919.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 81/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 82/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 83/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 84/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 85/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 86/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 87/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 88/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 89/100: Mejor Costo = 23932.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 90/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 91/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 92/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 93/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 94/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 95/100: Mejor Costo = 23919.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 96/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 97/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 98/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 99/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 100/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
#
#
# --- Ejecutando configuracion: N=100, M=0.8, C=0, T=10, G=30, tc=un punto ---
# Ejecucion 1/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 2/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 3/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 4/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 5/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 6/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 7/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 8/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 9/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 10/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 11/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 12/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 13/100: Mejor Costo = 23932.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 14/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 15/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 16/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 17/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 18/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 19/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 20/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 21/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 22/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 23/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 24/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 25/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 26/100: Mejor Costo = 23919.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 27/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 28/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 29/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 30/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 31/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 32/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 33/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 34/100: Mejor Costo = 23932.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 35/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 36/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 37/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 38/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 39/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 40/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 41/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 42/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 43/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 44/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 45/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 46/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 47/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 48/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 49/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 50/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 51/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 52/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 53/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 54/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 55/100: Mejor Costo = 23919.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 56/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 57/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 58/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 59/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 60/100: Mejor Costo = 23932.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 61/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 62/100: Mejor Costo = 23897.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 63/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 64/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 65/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 66/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 67/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 68/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 69/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 70/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 71/100: Mejor Costo = 23932.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 72/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 73/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 74/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 75/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 76/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 77/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 78/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 79/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 80/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 81/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 82/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 83/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 84/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 85/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 86/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 87/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 88/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 89/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 90/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 91/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 92/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 93/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 94/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 95/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 96/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 97/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 98/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 99/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 100/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
#
#
# --- Ejecutando configuracion: N=100, M=1, C=0, T=10, G=30, tc=un punto ---
# Ejecucion 1/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 2/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 3/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 4/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 5/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 6/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 7/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 8/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 9/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 10/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 11/100: Mejor Costo = 23919.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 12/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 13/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 14/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 15/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 16/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 17/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 18/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 19/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 20/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 21/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 22/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 23/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 24/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 25/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 26/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 27/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 28/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 29/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 30/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 31/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 32/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 33/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 34/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 35/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 36/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 37/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 38/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 39/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 40/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 41/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 42/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 43/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 44/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 45/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 46/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 47/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 48/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 49/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 50/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 51/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 52/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 53/100: Mejor Costo = 23897.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 54/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 55/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 56/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 57/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 58/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 59/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 60/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 61/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 62/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 63/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 64/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 65/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 66/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 67/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 68/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 69/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 70/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 71/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 72/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 73/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 74/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 75/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 76/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 77/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 78/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 79/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 80/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 81/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 82/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 83/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 84/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 85/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 86/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 87/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 88/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 89/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 90/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 91/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 92/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 93/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 94/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 95/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 96/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 97/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 98/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 99/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 100/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30

# %% [markdown]
# ## **RESUMEN**

# %%
tablas_resumen = {}
for nombre_configuracion, resultados_ejecuciones in resultados.items():
    costos = [res["mejor_costo"] for res in resultados_ejecuciones]
    tiempos = [res["tiempo_de_ejecucion"] for res in resultados_ejecuciones]
    mejor_costo = min(costos)
    peor_costo = max(costos)
    costo_promedio = np.mean(costos)
    desviacion_estandar_costo = np.std(costos)
    tiempo_promedio = np.mean(tiempos)
    desviacion_porcentual = (peor_costo - mejor_costo) / mejor_costo * 100 if mejor_costo != 0 else np.inf

    tablas_resumen[nombre_configuracion] = pd.DataFrame({
        "Métrica": ["Mejor Costo", "Peor Costo", "Costo Promedio", "Desviacion Estandar Costo", "Tiempo Promedio de Ejecucion (s)", "Desviacion Porcentual (%)"],
        "Valor": [f"{mejor_costo:.2f}", f"{peor_costo:.2f}", f"{costo_promedio:.2f}", f"{desviacion_estandar_costo:.2f}", f"{tiempo_promedio:.2f}", f"{desviacion_porcentual:.2f}"]
    })

    os.makedirs(os.path.join(path, file_name, nombre_configuracion), exist_ok=True)

# %%
for nombre_configuracion, resumen_df in tablas_resumen.items():
    resumen_df.to_csv(os.path.join(path, file_name, nombre_configuracion, f"resumen.csv"), index=False)

# %% [markdown]
# ## **GRÁFICAS**

# %%
from graficas import *

# %%
curva_corvengencia_individual(resultados, path, file_name)
box_plot_costos(resultados, path, file_name)
guardar_resultados(resultados, path, file_name, random_seed)
# Out:
# Texto guardado en resultados/UFLP-1/N=100, M=0, C=0, T=10, G=30, tc=un punto/mejores_soluciones.txt
# Texto guardado en resultados/UFLP-1/N=100, M=0.2, C=0, T=10, G=30, tc=un punto/mejores_soluciones.txt
# Texto guardado en resultados/UFLP-1/N=100, M=0.4, C=0, T=10, G=30, tc=un punto/mejores_soluciones.txt
# Texto guardado en resultados/UFLP-1/N=100, M=0.6, C=0, T=10, G=30, tc=un punto/mejores_soluciones.txt
# Texto guardado en resultados/UFLP-1/N=100, M=0.8, C=0, T=10, G=30, tc=un punto/mejores_soluciones.txt
# Texto guardado en resultados/UFLP-1/N=100, M=1, C=0, T=10, G=30, tc=un punto/mejores_soluciones.txt

# %% [markdown]
# ## **COMPARACIÓN**

# %%
curva_convergencia_comparacion(resultados, path, file_name, show=True, alphaa=0.005, NOMBRE="Buscando M")

# %%
box_plot_costos_comparacion(resultados, path, file_name, show=True, NOMBRE="Buscando M")

# %%
resumen_tablas(resultados, path, file_name, num_ejecuciones, tablas_resumen, random_seed, show=True, NOMBRE="Buscando M")

# %% [markdown]
# # **BÚSQUEDA DE HIPERPARÁMETROS**

# %%
num_ejecuciones = 100
resultados = {}
random_seed = 8

path = "resultados"
os.makedirs(os.path.join(path, file_name), exist_ok=True)

# %%
configuraciones = [
    {
        "tamaño_de_poblacion": 100,
        "tasa_de_mutacion": 1,
        "tasa_de_crossover": 0,
        "tamaño_del_torneo": 10,
        "maximo_de_generaciones": 30,
        "tipo_de_crossover": "un punto"
    },
    {
        "tamaño_de_poblacion": 100,
        "tasa_de_mutacion": 1,
        "tasa_de_crossover": 0.2,
        "tamaño_del_torneo": 10,
        "maximo_de_generaciones": 30,
        "tipo_de_crossover": "un punto"
    },
    {
        "tamaño_de_poblacion": 100,
        "tasa_de_mutacion": 1,
        "tasa_de_crossover": 0.4,
        "tamaño_del_torneo": 10,
        "maximo_de_generaciones": 30,
        "tipo_de_crossover": "un punto"
    },
    {
        "tamaño_de_poblacion": 100,
        "tasa_de_mutacion": 1,
        "tasa_de_crossover": 0.6,
        "tamaño_del_torneo": 10,
        "maximo_de_generaciones": 30,
        "tipo_de_crossover": "un punto"
    },
    {
        "tamaño_de_poblacion": 100,
        "tasa_de_mutacion": 1,
        "tasa_de_crossover": 0.8,
        "tamaño_del_torneo": 10,
        "maximo_de_generaciones": 30,
        "tipo_de_crossover": "un punto"
    },
    {
        "tamaño_de_poblacion": 100,
        "tasa_de_mutacion": 1,
        "tasa_de_crossover": 1,
        "tamaño_del_torneo": 10,
        "maximo_de_generaciones": 30,
        "tipo_de_crossover": "un punto"
    }
]

# %% [markdown]
# ## **EJECUCIÓN**

# %%
print(f"Ejecutando GA para {file_name} con semilla aleatoria: {random_seed}\n")

for config in configuraciones:
    nombre_configuracion = f"N={config['tamaño_de_poblacion']}, M={config['tasa_de_mutacion']}, C={config['tasa_de_crossover']}, T={config['tamaño_del_torneo']}, G={config['maximo_de_generaciones']}, tc={config['tipo_de_crossover']}"
    print(f"--- Ejecutando configuracion: {nombre_configuracion} ---")
    resultados[nombre_configuracion] = []

    for ejecucion in range(num_ejecuciones):
        ga = UFLP_GA(n_instalaciones, n_clientes, costos_fijos, costos_de_transporte,
                     config["tamaño_de_poblacion"], config["tasa_de_mutacion"], config["tasa_de_crossover"],
                     config["tamaño_del_torneo"], config["maximo_de_generaciones"])
        if config["tipo_de_crossover"] == "uniforme":
            ga._operador_de_crossover = ga._crossover_uniforme
        elif config["tipo_de_crossover"] == "un punto":
            ga._operador_de_crossover = ga._crossover_un_punto
        else:
            raise ValueError(f"Tipo de crossover desconocido: {config['tipo_de_crossover']}")

        mejor_solucion, mejor_fitness, historial_de_fitnesses, tiempo_de_ejecucion, num_generaciones = ga.run()
        resultados[nombre_configuracion].append({
            "mejor_solucion": mejor_solucion+1,
            "mejor_costo": mejor_fitness,
            "tiempo_de_ejecucion": tiempo_de_ejecucion,
            "num_generaciones": num_generaciones,
            "historial_de_fitnesses": historial_de_fitnesses
        })
        print(f"Ejecucion {ejecucion + 1}/{num_ejecuciones}: Mejor Costo = {mejor_fitness:.2f}, Tiempo = {tiempo_de_ejecucion:.2f}s, Generaciones = {num_generaciones}")
    print("\n")
# Out:
# Ejecutando GA para UFLP-1 con semilla aleatoria: 8
#
# --- Ejecutando configuracion: N=100, M=1, C=0, T=10, G=30, tc=un punto ---
# Ejecucion 1/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 2/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 3/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 4/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 5/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 6/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 7/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 8/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 9/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 10/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 11/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 12/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 13/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 14/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 15/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 16/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 17/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 18/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 19/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 20/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 21/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 22/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 23/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 24/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 25/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 26/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 27/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 28/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 29/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 30/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 31/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 32/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 33/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 34/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 35/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 36/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 37/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 38/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 39/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 40/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 41/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 42/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 43/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 44/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 45/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 46/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 47/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 48/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 49/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 50/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 51/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 52/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 53/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 54/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 55/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 56/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 57/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 58/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 59/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 60/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 61/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 62/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 63/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 64/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 65/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 66/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 67/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 68/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 69/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 70/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 71/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 72/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 73/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 74/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 75/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 76/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 77/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 78/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 79/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 80/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 81/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 82/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 83/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 84/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 85/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 86/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 87/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 88/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 89/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 90/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 91/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 92/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 93/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 94/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 95/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 96/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 97/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 98/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 99/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 100/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
#
#
# --- Ejecutando configuracion: N=100, M=1, C=0.2, T=10, G=30, tc=un punto ---
# Ejecucion 1/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 2/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 3/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 4/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 5/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 6/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 7/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 8/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 9/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 10/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 11/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 12/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 13/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 14/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 15/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 16/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 17/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 18/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 19/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 20/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 21/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 22/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 23/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 24/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 25/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 26/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 27/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 28/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 29/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 30/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 31/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 32/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 33/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 34/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 35/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 36/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 37/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 38/100: Mejor Costo = 23897.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 39/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 40/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 41/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 42/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 43/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 44/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 45/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 46/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 47/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 48/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 49/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 50/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 51/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 52/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 53/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 54/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 55/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 56/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 57/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 58/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 59/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 60/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 61/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 62/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 63/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 64/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 65/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 66/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 67/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 68/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 69/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 70/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 71/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 72/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 73/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 74/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 75/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 76/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 77/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 78/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 79/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 80/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 81/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 82/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 83/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 84/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 85/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 86/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 87/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 88/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 89/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 90/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 91/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 92/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 93/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 94/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 95/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 96/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 97/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 98/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 99/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 100/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
#
#
# --- Ejecutando configuracion: N=100, M=1, C=0.4, T=10, G=30, tc=un punto ---
# Ejecucion 1/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 2/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 3/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 4/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 5/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 6/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 7/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 8/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 9/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 10/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 11/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 12/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 13/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 14/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 15/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 16/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 17/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 18/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 19/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 20/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 21/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 22/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 23/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 24/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 25/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 26/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 27/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 28/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 29/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 30/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 31/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 32/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 33/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 34/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 35/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 36/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 37/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 38/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 39/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 40/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 41/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 42/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 43/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 44/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 45/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 46/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 47/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 48/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 49/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 50/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 51/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 52/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 53/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 54/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 55/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 56/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 57/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 58/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 59/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 60/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 61/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 62/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 63/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 64/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 65/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 66/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 67/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 68/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 69/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 70/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 71/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 72/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 73/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 74/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 75/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 76/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 77/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 78/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 79/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 80/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 81/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 82/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 83/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 84/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 85/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 86/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 87/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 88/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 89/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 90/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 91/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 92/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 93/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 94/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 95/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 96/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 97/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 98/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 99/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 100/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
#
#
# --- Ejecutando configuracion: N=100, M=1, C=0.6, T=10, G=30, tc=un punto ---
# Ejecucion 1/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 2/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 3/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 4/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 5/100: Mejor Costo = 23932.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 6/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 7/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 8/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 9/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 10/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 11/100: Mejor Costo = 23932.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 12/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 13/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 14/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 15/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 16/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 17/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 18/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 19/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 20/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 21/100: Mejor Costo = 23897.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 22/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 23/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 24/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 25/100: Mejor Costo = 23932.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 26/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 27/100: Mejor Costo = 23932.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 28/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 29/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 30/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 31/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 32/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 33/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 34/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 35/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 36/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 37/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 38/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 39/100: Mejor Costo = 23932.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 40/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 41/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 42/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 43/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 44/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 45/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 46/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 47/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 48/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 49/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 50/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 51/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 52/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 53/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 54/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 55/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 56/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 57/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 58/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 59/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 60/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 61/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 62/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 63/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 64/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 65/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 66/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 67/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 68/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 69/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 70/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 71/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 72/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 73/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 74/100: Mejor Costo = 23932.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 75/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 76/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 77/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 78/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 79/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 80/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 81/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 82/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 83/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 84/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 85/100: Mejor Costo = 23919.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 86/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 87/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 88/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 89/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 90/100: Mejor Costo = 23897.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 91/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 92/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 93/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 94/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 95/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 96/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 97/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 98/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 99/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 100/100: Mejor Costo = 23932.00, Tiempo = 0.07s, Generaciones = 30
#
#
# --- Ejecutando configuracion: N=100, M=1, C=0.8, T=10, G=30, tc=un punto ---
# Ejecucion 1/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 2/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 3/100: Mejor Costo = 23932.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 4/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 5/100: Mejor Costo = 23932.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 6/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 7/100: Mejor Costo = 24097.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 8/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 9/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 10/100: Mejor Costo = 24097.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 11/100: Mejor Costo = 23897.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 12/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 13/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 14/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 15/100: Mejor Costo = 23932.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 16/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 17/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 18/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 19/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 20/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 21/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 22/100: Mejor Costo = 23932.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 23/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 24/100: Mejor Costo = 23897.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 25/100: Mejor Costo = 23897.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 26/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 27/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 28/100: Mejor Costo = 23932.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 29/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 30/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 31/100: Mejor Costo = 23897.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 32/100: Mejor Costo = 23932.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 33/100: Mejor Costo = 23919.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 34/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 35/100: Mejor Costo = 23897.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 36/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 37/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 38/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 39/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 40/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 41/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 42/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 43/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 44/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 45/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 46/100: Mejor Costo = 24127.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 47/100: Mejor Costo = 23919.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 48/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 49/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 50/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 51/100: Mejor Costo = 23932.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 52/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 53/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 54/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 55/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 56/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 57/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 58/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 59/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 60/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 61/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 62/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 63/100: Mejor Costo = 23932.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 64/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 65/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 66/100: Mejor Costo = 23897.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 67/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 68/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 69/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 70/100: Mejor Costo = 23897.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 71/100: Mejor Costo = 23932.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 72/100: Mejor Costo = 23897.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 73/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 74/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 75/100: Mejor Costo = 23897.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 76/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 77/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 78/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 79/100: Mejor Costo = 23932.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 80/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 81/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 82/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 83/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 84/100: Mejor Costo = 23919.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 85/100: Mejor Costo = 23897.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 86/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 87/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 88/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 89/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 90/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 91/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 92/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 93/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 94/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 95/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 96/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 97/100: Mejor Costo = 23897.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 98/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 99/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 100/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
#
#
# --- Ejecutando configuracion: N=100, M=1, C=1, T=10, G=30, tc=un punto ---
# Ejecucion 1/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 2/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 3/100: Mejor Costo = 23932.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 4/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 5/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 6/100: Mejor Costo = 23897.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 7/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 8/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 9/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 10/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 11/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 12/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 13/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 14/100: Mejor Costo = 23932.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 15/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 16/100: Mejor Costo = 23932.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 17/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 18/100: Mejor Costo = 23932.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 19/100: Mejor Costo = 24128.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 20/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 21/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 22/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 23/100: Mejor Costo = 23919.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 24/100: Mejor Costo = 23932.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 25/100: Mejor Costo = 23897.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 26/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 27/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 28/100: Mejor Costo = 23919.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 29/100: Mejor Costo = 23919.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 30/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 31/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 32/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 33/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 34/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 35/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 36/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 37/100: Mejor Costo = 23919.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 38/100: Mejor Costo = 24105.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 39/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 40/100: Mejor Costo = 24183.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 41/100: Mejor Costo = 23932.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 42/100: Mejor Costo = 24183.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 43/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 44/100: Mejor Costo = 23897.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 45/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 46/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 47/100: Mejor Costo = 23919.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 48/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 49/100: Mejor Costo = 23897.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 50/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 51/100: Mejor Costo = 24462.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 52/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 53/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 54/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 55/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 56/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 57/100: Mejor Costo = 23932.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 58/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 59/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 60/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 61/100: Mejor Costo = 24105.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 62/100: Mejor Costo = 23919.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 63/100: Mejor Costo = 23897.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 64/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 65/100: Mejor Costo = 23919.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 66/100: Mejor Costo = 24183.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 67/100: Mejor Costo = 23897.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 68/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 69/100: Mejor Costo = 23919.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 70/100: Mejor Costo = 23919.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 71/100: Mejor Costo = 23919.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 72/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 73/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 74/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 75/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 76/100: Mejor Costo = 23919.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 77/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 78/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 79/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 80/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 81/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 82/100: Mejor Costo = 24127.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 83/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 84/100: Mejor Costo = 23897.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 85/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 86/100: Mejor Costo = 23897.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 87/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 88/100: Mejor Costo = 24127.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 89/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 90/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 91/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 92/100: Mejor Costo = 23919.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 93/100: Mejor Costo = 23897.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 94/100: Mejor Costo = 24097.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 95/100: Mejor Costo = 23919.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 96/100: Mejor Costo = 23897.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 97/100: Mejor Costo = 23897.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 98/100: Mejor Costo = 24097.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 99/100: Mejor Costo = 24128.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 100/100: Mejor Costo = 23919.00, Tiempo = 0.08s, Generaciones = 30

# %% [markdown]
# ## **RESUMEN**

# %%
tablas_resumen = {}
for nombre_configuracion, resultados_ejecuciones in resultados.items():
    costos = [res["mejor_costo"] for res in resultados_ejecuciones]
    tiempos = [res["tiempo_de_ejecucion"] for res in resultados_ejecuciones]
    mejor_costo = min(costos)
    peor_costo = max(costos)
    costo_promedio = np.mean(costos)
    desviacion_estandar_costo = np.std(costos)
    tiempo_promedio = np.mean(tiempos)
    desviacion_porcentual = (peor_costo - mejor_costo) / mejor_costo * 100 if mejor_costo != 0 else np.inf

    tablas_resumen[nombre_configuracion] = pd.DataFrame({
        "Métrica": ["Mejor Costo", "Peor Costo", "Costo Promedio", "Desviacion Estandar Costo", "Tiempo Promedio de Ejecucion (s)", "Desviacion Porcentual (%)"],
        "Valor": [f"{mejor_costo:.2f}", f"{peor_costo:.2f}", f"{costo_promedio:.2f}", f"{desviacion_estandar_costo:.2f}", f"{tiempo_promedio:.2f}", f"{desviacion_porcentual:.2f}"]
    })

    os.makedirs(os.path.join(path, file_name, nombre_configuracion), exist_ok=True)

# %%
for nombre_configuracion, resumen_df in tablas_resumen.items():
    resumen_df.to_csv(os.path.join(path, file_name, nombre_configuracion, f"resumen.csv"), index=False)

# %% [markdown]
# ## **GRÁFICAS**

# %%
from graficas import *

# %%
curva_corvengencia_individual(resultados, path, file_name)
box_plot_costos(resultados, path, file_name)
guardar_resultados(resultados, path, file_name, random_seed)
# Out:
# Texto guardado en resultados/UFLP-1/N=100, M=1, C=0, T=10, G=30, tc=un punto/mejores_soluciones.txt
# Texto guardado en resultados/UFLP-1/N=100, M=1, C=0.2, T=10, G=30, tc=un punto/mejores_soluciones.txt
# Texto guardado en resultados/UFLP-1/N=100, M=1, C=0.4, T=10, G=30, tc=un punto/mejores_soluciones.txt
# Texto guardado en resultados/UFLP-1/N=100, M=1, C=0.6, T=10, G=30, tc=un punto/mejores_soluciones.txt
# Texto guardado en resultados/UFLP-1/N=100, M=1, C=0.8, T=10, G=30, tc=un punto/mejores_soluciones.txt
# Texto guardado en resultados/UFLP-1/N=100, M=1, C=1, T=10, G=30, tc=un punto/mejores_soluciones.txt

# %% [markdown]
# ## **COMPARACIÓN**

# %%
curva_convergencia_comparacion(resultados, path, file_name, show=True, alphaa=0.005, NOMBRE="Buscando C")

# %%
box_plot_costos_comparacion(resultados, path, file_name, show=True, NOMBRE="Buscando C")

# %%
resumen_tablas(resultados, path, file_name, num_ejecuciones, tablas_resumen, random_seed, show=True, NOMBRE="Buscando C")

# %% [markdown]
# # **BÚSQUEDA DE HIPERPARÁMETROS**

# %%
num_ejecuciones = 100
resultados = {}
random_seed = 8

path = "resultados"
os.makedirs(os.path.join(path, file_name), exist_ok=True)

# %%
configuraciones = [
    {
        "tamaño_de_poblacion": 100,
        "tasa_de_mutacion": 1,
        "tasa_de_crossover": 0,
        "tamaño_del_torneo": 2,
        "maximo_de_generaciones": 30,
        "tipo_de_crossover": "un punto"
    },
    {
        "tamaño_de_poblacion": 100,
        "tasa_de_mutacion": 1,
        "tasa_de_crossover": 0,
        "tamaño_del_torneo": 10,
        "maximo_de_generaciones": 30,
        "tipo_de_crossover": "un punto"
    },
    {
        "tamaño_de_poblacion": 100,
        "tasa_de_mutacion": 1,
        "tasa_de_crossover": 0,
        "tamaño_del_torneo": 20,
        "maximo_de_generaciones": 30,
        "tipo_de_crossover": "un punto"
    },
    {
        "tamaño_de_poblacion": 100,
        "tasa_de_mutacion": 1,
        "tasa_de_crossover": 0,
        "tamaño_del_torneo": 30,
        "maximo_de_generaciones": 30,
        "tipo_de_crossover": "un punto"
    },
    {
        "tamaño_de_poblacion": 100,
        "tasa_de_mutacion": 1,
        "tasa_de_crossover": 0,
        "tamaño_del_torneo": 40,
        "maximo_de_generaciones": 30,
        "tipo_de_crossover": "un punto"
    },
    {
        "tamaño_de_poblacion": 100,
        "tasa_de_mutacion": 1,
        "tasa_de_crossover": 0,
        "tamaño_del_torneo": 50,
        "maximo_de_generaciones": 30,
        "tipo_de_crossover": "un punto"
    },
    {
        "tamaño_de_poblacion": 100,
        "tasa_de_mutacion": 1,
        "tasa_de_crossover": 0,
        "tamaño_del_torneo": 60,
        "maximo_de_generaciones": 30,
        "tipo_de_crossover": "un punto"
    }
]

# %% [markdown]
# ## **EJECUCIÓN**

# %%
print(f"Ejecutando GA para {file_name} con semilla aleatoria: {random_seed}\n")

for config in configuraciones:
    nombre_configuracion = f"N={config['tamaño_de_poblacion']}, M={config['tasa_de_mutacion']}, C={config['tasa_de_crossover']}, T={config['tamaño_del_torneo']}, G={config['maximo_de_generaciones']}, tc={config['tipo_de_crossover']}"
    print(f"--- Ejecutando configuracion: {nombre_configuracion} ---")
    resultados[nombre_configuracion] = []

    for ejecucion in range(num_ejecuciones):
        ga = UFLP_GA(n_instalaciones, n_clientes, costos_fijos, costos_de_transporte,
                     config["tamaño_de_poblacion"], config["tasa_de_mutacion"], config["tasa_de_crossover"],
                     config["tamaño_del_torneo"], config["maximo_de_generaciones"])
        if config["tipo_de_crossover"] == "uniforme":
            ga._operador_de_crossover = ga._crossover_uniforme
        elif config["tipo_de_crossover"] == "un punto":
            ga._operador_de_crossover = ga._crossover_un_punto
        else:
            raise ValueError(f"Tipo de crossover desconocido: {config['tipo_de_crossover']}")

        mejor_solucion, mejor_fitness, historial_de_fitnesses, tiempo_de_ejecucion, num_generaciones = ga.run()
        resultados[nombre_configuracion].append({
            "mejor_solucion": mejor_solucion+1,
            "mejor_costo": mejor_fitness,
            "tiempo_de_ejecucion": tiempo_de_ejecucion,
            "num_generaciones": num_generaciones,
            "historial_de_fitnesses": historial_de_fitnesses
        })
        print(f"Ejecucion {ejecucion + 1}/{num_ejecuciones}: Mejor Costo = {mejor_fitness:.2f}, Tiempo = {tiempo_de_ejecucion:.2f}s, Generaciones = {num_generaciones}")
    print("\n")
# Out:
# Ejecutando GA para UFLP-1 con semilla aleatoria: 8
#
# --- Ejecutando configuracion: N=100, M=1, C=0, T=2, G=30, tc=un punto ---
# Ejecucion 1/100: Mejor Costo = 24609.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 2/100: Mejor Costo = 25651.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 3/100: Mejor Costo = 25545.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 4/100: Mejor Costo = 24922.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 5/100: Mejor Costo = 23919.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 6/100: Mejor Costo = 25031.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 7/100: Mejor Costo = 24097.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 8/100: Mejor Costo = 24906.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 9/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 10/100: Mejor Costo = 26444.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 11/100: Mejor Costo = 23919.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 12/100: Mejor Costo = 23919.00, Tiempo = 0.15s, Generaciones = 30
# Ejecucion 13/100: Mejor Costo = 24973.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 14/100: Mejor Costo = 24097.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 15/100: Mejor Costo = 24097.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 16/100: Mejor Costo = 24278.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 17/100: Mejor Costo = 24097.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 18/100: Mejor Costo = 24462.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 19/100: Mejor Costo = 24278.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 20/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 21/100: Mejor Costo = 24906.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 22/100: Mejor Costo = 24105.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 23/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 24/100: Mejor Costo = 25030.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 25/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 26/100: Mejor Costo = 25025.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 27/100: Mejor Costo = 23919.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 28/100: Mejor Costo = 24278.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 29/100: Mejor Costo = 24097.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 30/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 31/100: Mejor Costo = 23932.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 32/100: Mejor Costo = 23932.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 33/100: Mejor Costo = 24183.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 34/100: Mejor Costo = 23932.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 35/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 36/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 37/100: Mejor Costo = 23919.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 38/100: Mejor Costo = 25347.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 39/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 40/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 41/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 42/100: Mejor Costo = 23932.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 43/100: Mejor Costo = 23932.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 44/100: Mejor Costo = 24659.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 45/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 46/100: Mejor Costo = 24097.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 47/100: Mejor Costo = 23932.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 48/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 49/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 50/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 51/100: Mejor Costo = 24935.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 52/100: Mejor Costo = 25068.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 53/100: Mejor Costo = 24601.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 54/100: Mejor Costo = 23919.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 55/100: Mejor Costo = 24765.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 56/100: Mejor Costo = 24183.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 57/100: Mejor Costo = 23919.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 58/100: Mejor Costo = 23919.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 59/100: Mejor Costo = 24097.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 60/100: Mejor Costo = 23932.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 61/100: Mejor Costo = 24278.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 62/100: Mejor Costo = 24278.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 63/100: Mejor Costo = 24922.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 64/100: Mejor Costo = 24127.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 65/100: Mejor Costo = 24609.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 66/100: Mejor Costo = 23932.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 67/100: Mejor Costo = 25031.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 68/100: Mejor Costo = 24655.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 69/100: Mejor Costo = 24906.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 70/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 71/100: Mejor Costo = 23919.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 72/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 73/100: Mejor Costo = 24045.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 74/100: Mejor Costo = 23932.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 75/100: Mejor Costo = 23897.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 76/100: Mejor Costo = 24183.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 77/100: Mejor Costo = 24459.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 78/100: Mejor Costo = 23897.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 79/100: Mejor Costo = 23932.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 80/100: Mejor Costo = 23932.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 81/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 82/100: Mejor Costo = 24278.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 83/100: Mejor Costo = 25030.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 84/100: Mejor Costo = 25628.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 85/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 86/100: Mejor Costo = 24183.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 87/100: Mejor Costo = 23897.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 88/100: Mejor Costo = 23468.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 89/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 90/100: Mejor Costo = 23932.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 91/100: Mejor Costo = 24906.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 92/100: Mejor Costo = 24105.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 93/100: Mejor Costo = 24183.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 94/100: Mejor Costo = 24097.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 95/100: Mejor Costo = 24278.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 96/100: Mejor Costo = 24973.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 97/100: Mejor Costo = 25134.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 98/100: Mejor Costo = 24191.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 99/100: Mejor Costo = 24183.00, Tiempo = 0.05s, Generaciones = 30
# Ejecucion 100/100: Mejor Costo = 25374.00, Tiempo = 0.05s, Generaciones = 30
#
#
# --- Ejecutando configuracion: N=100, M=1, C=0, T=10, G=30, tc=un punto ---
# Ejecucion 1/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 2/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 3/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 4/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 5/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 6/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 7/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 8/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 9/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 10/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 11/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 12/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 13/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 14/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 15/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 16/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 17/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 18/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 19/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 20/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 21/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 22/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 23/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 24/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 25/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 26/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 27/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 28/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 29/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 30/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 31/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 32/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 33/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 34/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 35/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 36/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 37/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 38/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 39/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 40/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 41/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 42/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 43/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 44/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 45/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 46/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 47/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 48/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 49/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 50/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 51/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 52/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 53/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 54/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 55/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 56/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 57/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 58/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 59/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 60/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 61/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 62/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 63/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 64/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 65/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 66/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 67/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 68/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 69/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 70/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 71/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 72/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 73/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 74/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 75/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 76/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 77/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 78/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 79/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 80/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 81/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 82/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 83/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 84/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 85/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 86/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 87/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 88/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 89/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 90/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 91/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 92/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 93/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 94/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 95/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 96/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 97/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 98/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 99/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 100/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
#
#
# --- Ejecutando configuracion: N=100, M=1, C=0, T=20, G=30, tc=un punto ---
# Ejecucion 1/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 2/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 3/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 4/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 5/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 6/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 7/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 8/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 9/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 10/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 11/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 12/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 13/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 14/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 15/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 16/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 17/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 18/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 19/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 20/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 21/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 22/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 23/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 24/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 25/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 26/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 27/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 28/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 29/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 30/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 31/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 32/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 33/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 34/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 35/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 36/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 37/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 38/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 39/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 40/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 41/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 42/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 43/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 44/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 45/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 46/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 47/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 48/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 49/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 50/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 51/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 52/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 53/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 54/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 55/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 56/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 57/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 58/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 59/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 60/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 61/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 62/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 63/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 64/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 65/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 66/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 67/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 68/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 69/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 70/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 71/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 72/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 73/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 74/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 75/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 76/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 77/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 78/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 79/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 80/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 81/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 82/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 83/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 84/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 85/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 86/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 87/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 88/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 89/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 90/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 91/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 92/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 93/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 94/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 95/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 96/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 97/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 98/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 99/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 100/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
#
#
# --- Ejecutando configuracion: N=100, M=1, C=0, T=30, G=30, tc=un punto ---
# Ejecucion 1/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 2/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 3/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 4/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 5/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 6/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 7/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 8/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 9/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 10/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 11/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 12/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 13/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 14/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 15/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 16/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 17/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 18/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 19/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 20/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 21/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 22/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 23/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 24/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 25/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 26/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 27/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 28/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 29/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 30/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 31/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 32/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 33/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 34/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 35/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 36/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 37/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 38/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 39/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 40/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 41/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 42/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 43/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 44/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 45/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 46/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 47/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 48/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 49/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 50/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 51/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 52/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 53/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 54/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 55/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 56/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 57/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 58/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 59/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 60/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 61/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 62/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 63/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 64/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 65/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 66/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 67/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 68/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 69/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 70/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 71/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 72/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 73/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 74/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 75/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 76/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 77/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 78/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 79/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 80/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 81/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 82/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 83/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 84/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 85/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 86/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 87/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 88/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 89/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 90/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 91/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 92/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 93/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 94/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 95/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 96/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 97/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 98/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 99/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 100/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
#
#
# --- Ejecutando configuracion: N=100, M=1, C=0, T=40, G=30, tc=un punto ---
# Ejecucion 1/100: Mejor Costo = 23468.00, Tiempo = 0.14s, Generaciones = 30
# Ejecucion 2/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 3/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 4/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 5/100: Mejor Costo = 23468.00, Tiempo = 0.13s, Generaciones = 30
# Ejecucion 6/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 7/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 8/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 9/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 10/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 11/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 12/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 13/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 14/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 15/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 16/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 17/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 18/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 19/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 20/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 21/100: Mejor Costo = 23468.00, Tiempo = 0.13s, Generaciones = 30
# Ejecucion 22/100: Mejor Costo = 23468.00, Tiempo = 0.13s, Generaciones = 30
# Ejecucion 23/100: Mejor Costo = 23468.00, Tiempo = 0.17s, Generaciones = 30
# Ejecucion 24/100: Mejor Costo = 23468.00, Tiempo = 0.15s, Generaciones = 30
# Ejecucion 25/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 26/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 27/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 28/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 29/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 30/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 31/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 32/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 33/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 34/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 35/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 36/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 37/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 38/100: Mejor Costo = 23468.00, Tiempo = 0.12s, Generaciones = 30
# Ejecucion 39/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 40/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 41/100: Mejor Costo = 23468.00, Tiempo = 0.12s, Generaciones = 30
# Ejecucion 42/100: Mejor Costo = 23468.00, Tiempo = 0.13s, Generaciones = 30
# Ejecucion 43/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 44/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 45/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 46/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 47/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 48/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 49/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 50/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 51/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 52/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 53/100: Mejor Costo = 23468.00, Tiempo = 0.15s, Generaciones = 30
# Ejecucion 54/100: Mejor Costo = 23468.00, Tiempo = 0.12s, Generaciones = 30
# Ejecucion 55/100: Mejor Costo = 23468.00, Tiempo = 0.12s, Generaciones = 30
# Ejecucion 56/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 57/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 58/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 59/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 60/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 61/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 62/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 63/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 64/100: Mejor Costo = 23468.00, Tiempo = 0.14s, Generaciones = 30
# Ejecucion 65/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 66/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 67/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 68/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 69/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 70/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 71/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 72/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 73/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 74/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 75/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 76/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 77/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 78/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 79/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 80/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 81/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 82/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 83/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 84/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 85/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 86/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 87/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 88/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 89/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 90/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 91/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 92/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 93/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 94/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 95/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 96/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 97/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 98/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 99/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 100/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
#
#
# --- Ejecutando configuracion: N=100, M=1, C=0, T=50, G=30, tc=un punto ---
# Ejecucion 1/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 2/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 3/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 4/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 5/100: Mejor Costo = 23468.00, Tiempo = 0.12s, Generaciones = 30
# Ejecucion 6/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 7/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 8/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 9/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 10/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 11/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 12/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 13/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 14/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 15/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 16/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 17/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 18/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 19/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 20/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 21/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 22/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 23/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 24/100: Mejor Costo = 23468.00, Tiempo = 0.12s, Generaciones = 30
# Ejecucion 25/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 26/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 27/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 28/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 29/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 30/100: Mejor Costo = 23468.00, Tiempo = 0.15s, Generaciones = 30
# Ejecucion 31/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 32/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 33/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 34/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 35/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 36/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 37/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 38/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 39/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 40/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 41/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 42/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 43/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 44/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 45/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 46/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 47/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 48/100: Mejor Costo = 23468.00, Tiempo = 0.12s, Generaciones = 30
# Ejecucion 49/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 50/100: Mejor Costo = 23468.00, Tiempo = 0.12s, Generaciones = 30
# Ejecucion 51/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 52/100: Mejor Costo = 23468.00, Tiempo = 0.19s, Generaciones = 30
# Ejecucion 53/100: Mejor Costo = 23468.00, Tiempo = 0.14s, Generaciones = 30
# Ejecucion 54/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 55/100: Mejor Costo = 23468.00, Tiempo = 0.12s, Generaciones = 30
# Ejecucion 56/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 57/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 58/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 59/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 60/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 61/100: Mejor Costo = 23468.00, Tiempo = 0.12s, Generaciones = 30
# Ejecucion 62/100: Mejor Costo = 23468.00, Tiempo = 0.13s, Generaciones = 30
# Ejecucion 63/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 64/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 65/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 66/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 67/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 68/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 69/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 70/100: Mejor Costo = 23468.00, Tiempo = 0.13s, Generaciones = 30
# Ejecucion 71/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 72/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 73/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 74/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 75/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 76/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 77/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 78/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 79/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 80/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 81/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 82/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 83/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 84/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 85/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 86/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 87/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 88/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 89/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 90/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 91/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 92/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 93/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 94/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 95/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 96/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 97/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 98/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
# Ejecucion 99/100: Mejor Costo = 23468.00, Tiempo = 0.12s, Generaciones = 30
# Ejecucion 100/100: Mejor Costo = 23468.00, Tiempo = 0.10s, Generaciones = 30
#
#
# --- Ejecutando configuracion: N=100, M=1, C=0, T=60, G=30, tc=un punto ---
# Ejecucion 1/100: Mejor Costo = 23468.00, Tiempo = 0.12s, Generaciones = 30
# Ejecucion 2/100: Mejor Costo = 23468.00, Tiempo = 0.12s, Generaciones = 30
# Ejecucion 3/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 4/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 5/100: Mejor Costo = 23468.00, Tiempo = 0.12s, Generaciones = 30
# Ejecucion 6/100: Mejor Costo = 23468.00, Tiempo = 0.12s, Generaciones = 30
# Ejecucion 7/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 8/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 9/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 10/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 11/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 12/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 13/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 14/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 15/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 16/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 17/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 18/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 19/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 20/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 21/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 22/100: Mejor Costo = 23468.00, Tiempo = 0.12s, Generaciones = 30
# Ejecucion 23/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 24/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 25/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 26/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 27/100: Mejor Costo = 23468.00, Tiempo = 0.13s, Generaciones = 30
# Ejecucion 28/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 29/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 30/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 31/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 32/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 33/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 34/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 35/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 36/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 37/100: Mejor Costo = 23468.00, Tiempo = 0.12s, Generaciones = 30
# Ejecucion 38/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 39/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 40/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 41/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 42/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 43/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 44/100: Mejor Costo = 23468.00, Tiempo = 0.13s, Generaciones = 30
# Ejecucion 45/100: Mejor Costo = 23468.00, Tiempo = 0.15s, Generaciones = 30
# Ejecucion 46/100: Mejor Costo = 23468.00, Tiempo = 0.21s, Generaciones = 30
# Ejecucion 47/100: Mejor Costo = 23468.00, Tiempo = 0.16s, Generaciones = 30
# Ejecucion 48/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 49/100: Mejor Costo = 23468.00, Tiempo = 0.13s, Generaciones = 30
# Ejecucion 50/100: Mejor Costo = 23468.00, Tiempo = 0.12s, Generaciones = 30
# Ejecucion 51/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 52/100: Mejor Costo = 23468.00, Tiempo = 0.13s, Generaciones = 30
# Ejecucion 53/100: Mejor Costo = 23468.00, Tiempo = 0.13s, Generaciones = 30
# Ejecucion 54/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 55/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 56/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 57/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 58/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 59/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 60/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 61/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 62/100: Mejor Costo = 23468.00, Tiempo = 0.13s, Generaciones = 30
# Ejecucion 63/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 64/100: Mejor Costo = 23468.00, Tiempo = 0.12s, Generaciones = 30
# Ejecucion 65/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 66/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 67/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 68/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 69/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 70/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 71/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 72/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 73/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 74/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 75/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 76/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 77/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 78/100: Mejor Costo = 23468.00, Tiempo = 0.12s, Generaciones = 30
# Ejecucion 79/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 80/100: Mejor Costo = 23468.00, Tiempo = 0.13s, Generaciones = 30
# Ejecucion 81/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 82/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 83/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 84/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 85/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 86/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 87/100: Mejor Costo = 23468.00, Tiempo = 0.13s, Generaciones = 30
# Ejecucion 88/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 89/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 90/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 91/100: Mejor Costo = 23919.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 92/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 93/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 94/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 95/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 96/100: Mejor Costo = 23468.00, Tiempo = 0.13s, Generaciones = 30
# Ejecucion 97/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30
# Ejecucion 98/100: Mejor Costo = 23468.00, Tiempo = 0.13s, Generaciones = 30
# Ejecucion 99/100: Mejor Costo = 23468.00, Tiempo = 0.13s, Generaciones = 30
# Ejecucion 100/100: Mejor Costo = 23468.00, Tiempo = 0.11s, Generaciones = 30

# %% [markdown]
# ## **RESUMEN**

# %%
tablas_resumen = {}
for nombre_configuracion, resultados_ejecuciones in resultados.items():
    costos = [res["mejor_costo"] for res in resultados_ejecuciones]
    tiempos = [res["tiempo_de_ejecucion"] for res in resultados_ejecuciones]
    mejor_costo = min(costos)
    peor_costo = max(costos)
    costo_promedio = np.mean(costos)
    desviacion_estandar_costo = np.std(costos)
    tiempo_promedio = np.mean(tiempos)
    desviacion_porcentual = (peor_costo - mejor_costo) / mejor_costo * 100 if mejor_costo != 0 else np.inf

    tablas_resumen[nombre_configuracion] = pd.DataFrame({
        "Métrica": ["Mejor Costo", "Peor Costo", "Costo Promedio", "Desviacion Estandar Costo", "Tiempo Promedio de Ejecucion (s)", "Desviacion Porcentual (%)"],
        "Valor": [f"{mejor_costo:.2f}", f"{peor_costo:.2f}", f"{costo_promedio:.2f}", f"{desviacion_estandar_costo:.2f}", f"{tiempo_promedio:.2f}", f"{desviacion_porcentual:.2f}"]
    })

    os.makedirs(os.path.join(path, file_name, nombre_configuracion), exist_ok=True)

# %%
for nombre_configuracion, resumen_df in tablas_resumen.items():
    resumen_df.to_csv(os.path.join(path, file_name, nombre_configuracion, f"resumen.csv"), index=False)

# %% [markdown]
# ## **GRÁFICAS**

# %%
from graficas import *

# %%
curva_corvengencia_individual(resultados, path, file_name)
box_plot_costos(resultados, path, file_name)
guardar_resultados(resultados, path, file_name, random_seed)
# Out:
# Texto guardado en resultados/UFLP-1/N=100, M=1, C=0, T=2, G=30, tc=un punto/mejores_soluciones.txt
# Texto guardado en resultados/UFLP-1/N=100, M=1, C=0, T=10, G=30, tc=un punto/mejores_soluciones.txt
# Texto guardado en resultados/UFLP-1/N=100, M=1, C=0, T=20, G=30, tc=un punto/mejores_soluciones.txt
# Texto guardado en resultados/UFLP-1/N=100, M=1, C=0, T=30, G=30, tc=un punto/mejores_soluciones.txt
# Texto guardado en resultados/UFLP-1/N=100, M=1, C=0, T=40, G=30, tc=un punto/mejores_soluciones.txt
# Texto guardado en resultados/UFLP-1/N=100, M=1, C=0, T=50, G=30, tc=un punto/mejores_soluciones.txt
# Texto guardado en resultados/UFLP-1/N=100, M=1, C=0, T=60, G=30, tc=un punto/mejores_soluciones.txt

# %% [markdown]
# ## **COMPARACIÓN**

# %%
curva_convergencia_comparacion(resultados, path, file_name, show=True, alphaa=0.005, NOMBRE="Buscando T")

# %%
box_plot_costos_comparacion(resultados, path, file_name, show=True, NOMBRE="Buscando T")

# %%
resumen_tablas(resultados, path, file_name, num_ejecuciones, tablas_resumen, random_seed, show=True, NOMBRE="Buscando T")

# %% [markdown]
# # **BÚSQUEDA DE HIPERPARÁMETROS**

# %%
num_ejecuciones = 100
resultados = {}
random_seed = 8

path = "resultados"
os.makedirs(os.path.join(path, file_name), exist_ok=True)

# %%
configuraciones = [
    {
        "tamaño_de_poblacion": 100,
        "tasa_de_mutacion": 1,
        "tasa_de_crossover": 0,
        "tamaño_del_torneo": 10,
        "maximo_de_generaciones": 30,
        "tipo_de_crossover": "un punto"
    },
    {
        "tamaño_de_poblacion": 100,
        "tasa_de_mutacion": 1,
        "tasa_de_crossover": 0,
        "tamaño_del_torneo": 10,
        "maximo_de_generaciones": 30,
        "tipo_de_crossover": "uniforme"
    }
]

# %% [markdown]
# ## **EJECUCIÓN**

# %%
print(f"Ejecutando GA para {file_name} con semilla aleatoria: {random_seed}\n")

for config in configuraciones:
    nombre_configuracion = f"N={config['tamaño_de_poblacion']}, M={config['tasa_de_mutacion']}, C={config['tasa_de_crossover']}, T={config['tamaño_del_torneo']}, G={config['maximo_de_generaciones']}, tc={config['tipo_de_crossover']}"
    print(f"--- Ejecutando configuracion: {nombre_configuracion} ---")
    resultados[nombre_configuracion] = []

    for ejecucion in range(num_ejecuciones):
        ga = UFLP_GA(n_instalaciones, n_clientes, costos_fijos, costos_de_transporte,
                     config["tamaño_de_poblacion"], config["tasa_de_mutacion"], config["tasa_de_crossover"],
                     config["tamaño_del_torneo"], config["maximo_de_generaciones"])
        if config["tipo_de_crossover"] == "uniforme":
            ga._operador_de_crossover = ga._crossover_uniforme
        elif config["tipo_de_crossover"] == "un punto":
            ga._operador_de_crossover = ga._crossover_un_punto
        else:
            raise ValueError(f"Tipo de crossover desconocido: {config['tipo_de_crossover']}")

        mejor_solucion, mejor_fitness, historial_de_fitnesses, tiempo_de_ejecucion, num_generaciones = ga.run()
        resultados[nombre_configuracion].append({
            "mejor_solucion": mejor_solucion+1,
            "mejor_costo": mejor_fitness,
            "tiempo_de_ejecucion": tiempo_de_ejecucion,
            "num_generaciones": num_generaciones,
            "historial_de_fitnesses": historial_de_fitnesses
        })
        print(f"Ejecucion {ejecucion + 1}/{num_ejecuciones}: Mejor Costo = {mejor_fitness:.2f}, Tiempo = {tiempo_de_ejecucion:.2f}s, Generaciones = {num_generaciones}")
    print("\n")
# Out:
# Ejecutando GA para UFLP-1 con semilla aleatoria: 8
#
# --- Ejecutando configuracion: N=100, M=1, C=0, T=10, G=30, tc=un punto ---
# Ejecucion 1/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 2/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 3/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 4/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 5/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 6/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 7/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 8/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 9/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 10/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 11/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 12/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 13/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 14/100: Mejor Costo = 23919.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 15/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 16/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 17/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 18/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 19/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 20/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 21/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 22/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 23/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 24/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 25/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 26/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 27/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 28/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 29/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 30/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 31/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 32/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 33/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 34/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 35/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 36/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 37/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 38/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 39/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 40/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 41/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 42/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 43/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 44/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 45/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 46/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 47/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 48/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 49/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 50/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 51/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 52/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 53/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 54/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 55/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 56/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 57/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 58/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 59/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 60/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 61/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 62/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 63/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 64/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 65/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 66/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 67/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 68/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 69/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 70/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 71/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 72/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 73/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 74/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 75/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 76/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 77/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 78/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 79/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 80/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 81/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 82/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 83/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 84/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 85/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 86/100: Mejor Costo = 23932.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 87/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 88/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 89/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 90/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 91/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 92/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 93/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 94/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 95/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 96/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 97/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 98/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 99/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 100/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
#
#
# --- Ejecutando configuracion: N=100, M=1, C=0, T=10, G=30, tc=uniforme ---
# Ejecucion 1/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 2/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 3/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 4/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 5/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 6/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 7/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 8/100: Mejor Costo = 23932.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 9/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 10/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 11/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 12/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 13/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 14/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 15/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 16/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 17/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 18/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 19/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 20/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 21/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 22/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 23/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 24/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 25/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 26/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 27/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 28/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 29/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 30/100: Mejor Costo = 23932.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 31/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 32/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 33/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 34/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 35/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 36/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 37/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 38/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 39/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 40/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 41/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 42/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 43/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 44/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 45/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 46/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 47/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 48/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 49/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 50/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 51/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 52/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 53/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 54/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 55/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 56/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 57/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 58/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 59/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 60/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 61/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 62/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 63/100: Mejor Costo = 23468.00, Tiempo = 0.09s, Generaciones = 30
# Ejecucion 64/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 65/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 66/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 67/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 68/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 69/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 70/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 71/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 72/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 73/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 74/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 75/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 76/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 77/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 78/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 79/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 80/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 81/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 82/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 83/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 84/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 85/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 86/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 87/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 88/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 89/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 90/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 91/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 92/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 93/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 94/100: Mejor Costo = 23468.00, Tiempo = 0.07s, Generaciones = 30
# Ejecucion 95/100: Mejor Costo = 23468.00, Tiempo = 0.08s, Generaciones = 30
# Ejecucion 96/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 97/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 98/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 99/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30
# Ejecucion 100/100: Mejor Costo = 23468.00, Tiempo = 0.06s, Generaciones = 30

# %% [markdown]
# ## **RESUMEN**

# %%
tablas_resumen = {}
for nombre_configuracion, resultados_ejecuciones in resultados.items():
    costos = [res["mejor_costo"] for res in resultados_ejecuciones]
    tiempos = [res["tiempo_de_ejecucion"] for res in resultados_ejecuciones]
    mejor_costo = min(costos)
    peor_costo = max(costos)
    costo_promedio = np.mean(costos)
    desviacion_estandar_costo = np.std(costos)
    tiempo_promedio = np.mean(tiempos)
    desviacion_porcentual = (peor_costo - mejor_costo) / mejor_costo * 100 if mejor_costo != 0 else np.inf

    tablas_resumen[nombre_configuracion] = pd.DataFrame({
        "Métrica": ["Mejor Costo", "Peor Costo", "Costo Promedio", "Desviacion Estandar Costo", "Tiempo Promedio de Ejecucion (s)", "Desviacion Porcentual (%)"],
        "Valor": [f"{mejor_costo:.2f}", f"{peor_costo:.2f}", f"{costo_promedio:.2f}", f"{desviacion_estandar_costo:.2f}", f"{tiempo_promedio:.2f}", f"{desviacion_porcentual:.2f}"]
    })

    os.makedirs(os.path.join(path, file_name, nombre_configuracion), exist_ok=True)

# %%
for nombre_configuracion, resumen_df in tablas_resumen.items():
    resumen_df.to_csv(os.path.join(path, file_name, nombre_configuracion, f"resumen.csv"), index=False)

# %% [markdown]
# ## **GRÁFICAS**

# %%
from graficas import *

# %%
curva_corvengencia_individual(resultados, path, file_name)
box_plot_costos(resultados, path, file_name)
guardar_resultados(resultados, path, file_name, random_seed)
# Out:
# Texto guardado en resultados/UFLP-1/N=100, M=1, C=0, T=10, G=30, tc=un punto/mejores_soluciones.txt
# Texto guardado en resultados/UFLP-1/N=100, M=1, C=0, T=10, G=30, tc=uniforme/mejores_soluciones.txt

# %% [markdown]
# ## **COMPARACIÓN**

# %%
curva_convergencia_comparacion(resultados, path, file_name, show=True, alphaa=0.005, NOMBRE="Buscando tc")

# %%
box_plot_costos_comparacion(resultados, path, file_name, show=True, NOMBRE="Buscando tc")

# %%
resumen_tablas(resultados, path, file_name, num_ejecuciones, tablas_resumen, random_seed, show=True, NOMBRE="Buscando tc")
